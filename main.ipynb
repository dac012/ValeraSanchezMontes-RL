# %% [markdown]
# <a href="https://colab.research.google.com/github/dac012/ValeraSanchezMontes-RL/blob/main/main.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
#     Authors: David Valera López
#              Lucía Sánchez Montes Gómez
#
#     Emails: d.valeralopez1@um.es
#             lucia.s1@um.es

# %% [markdown]
# Este notebook sirve como enlace para poder acceder a notebooks principales de cada parte:
#
# ### K bandidos
#
# - [Notebook main en k-brazos](https://colab.research.google.com/github/dac012/ValeraSanchezMontes-RL/blob/main/k_brazos/main.ipynb)
#
# ### Entornos complejos
#
# - [Notebook main en Entornos Complejos](https://colab.research.google.com/github/dac012/ValeraSanchezMontes-RL/blob/main/Entornos_Complejos/main.ipynb)
