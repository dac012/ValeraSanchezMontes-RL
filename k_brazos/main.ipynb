# %% [markdown]
# <a href="https://colab.research.google.com/github/dac012/ValeraSanchezMontes-RL/blob/main/k_brazos/main.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
#     Authors: David Valera López
#              Lucía Sánchez Montes Gómez
#
#     Emails: d.valeralopez1@um.es
#             lucia.s1@um.es

# %% [markdown]
# Este notebook sirve como enlace para poder acceder a todos los notebooks implementados:
#
# - [Notebook usando distribución Bernoulli con todos los algoritmos](https://colab.research.google.com/github/dac012/ValeraSanchezMontes-RL/blob/main/k_brazos/bernoulli.ipynb)
# - [Notebook usando distribución Binomial con todos los algoritmos](https://colab.research.google.com/github/dac012/ValeraSanchezMontes-RL/blob/main/k_brazos/binomial.ipynb)
# - [Notebook usando distribución Normal con todos los algoritmos](https://colab.research.google.com/github/dac012/ValeraSanchezMontes-RL/blob/main/k_brazos/normal.ipynb)
